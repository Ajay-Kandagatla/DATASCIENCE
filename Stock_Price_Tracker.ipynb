# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajay-Kandagatla/DATASCIENCE/blob/main/Stock_Price_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stock Price Tracker

# %% [markdown]
# 🎯 Objective
# Track the historical price of a selected stock (e.g., Apple – AAPL,'TSLA', 'MSFT', 'INFY.NS'), analyze trends, and visualize price movement and moving averages using Python.

# %%
# Importing Required Libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Step 1: Define the stock and date range
stock_symbol = 'AAPL'  # You can change to 'TSLA', 'MSFT', 'INFY.NS', etc.
start_date = '2023-01-01'
end_date = '2024-12-31'

# %%
# Step 2: Fetch stock data
stock_data = yf.download(stock_symbol, start=start_date, end=end_date)
# Out:
# /tmp/ipython-input-52-2135029075.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download(stock_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
# Step 3: Show basic info
print("Head of the Data:")
print(stock_data.head(10))
# Out:
# Head of the Data:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.470604  129.226044  122.582112  128.613978  112117500
# 2023-01-04  124.744110  127.014701  123.480480  125.267331   89113600
# 2023-01-05  123.421242  126.136075  123.164572  125.504260   80962700
# 2023-01-06  127.962410  128.623840  123.292902  124.398582   87754700
# 2023-01-09  128.485641  131.703962  128.228972  128.801557   70790800
# 2023-01-10  129.058228  129.581449  126.481603  128.594237   63896200
# 2023-01-11  131.782944  131.802677  128.791692  129.571583   69458900
# 2023-01-12  131.703979  132.543101  129.759170  132.167970   71379600
# 2023-01-13  133.036697  133.194655  129.976349  130.341613   57809700
# 2023-01-17  134.201614  135.534342  132.414763  133.105808   63646600

# %%
# Step 4: Plot Closing Price
plt.figure(figsize=(12, 6))
plt.plot(stock_data['Close'], label='Closing Price')
plt.title(f'{stock_symbol} Closing Price')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Step 5: Calculate Moving Average (Optional)
stock_data['MA50'] = stock_data['Close'].rolling(window=50).mean()

# %%
# Step 6: Plot Closing Price and MA50
plt.figure(figsize=(12, 6))
plt.plot(stock_data['Close'], label='Close Price')
plt.plot(stock_data['MA50'], label='50-Day MA', color='orange')
plt.title(f'{stock_symbol} Price & 50-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 📈 What This Project Does:
# Pulls historical data of a selected stock.
#
# Displays and plots the closing price over time.
#
# Adds a 50-day moving average to analyze trends.
